# %% [markdown]
# # Mini-Project: Data Wrangling and Transformation with Pandas
#
# Working with tabular data is a necessity for anyone with enterprises having a majority of their data in relational databases and flat files. This mini-project is adopted from the excellent tutorial on pandas by Brandon Rhodes which you have watched earlier in the Data Wrangling Unit. In this mini-project, we will be looking at some interesting data based on movie data from the IMDB.
#
# This assignment should help you reinforce the concepts you learnt in the curriculum for Data Wrangling and sharpen your skills in using Pandas. Good Luck!

# %% [markdown]
# ### Please make sure you have one of the more recent versions of Pandas

# %%
# !pip install pandas==0.23
# Out:
# ...
#     100% |████████████████████████████████| 11.7MB 4.4MB/s eta 0:00:01
# ...
# pyspark 2.4.0 requires py4j==0.10.7, which is not installed.
# ...
#   Found existing installation: pandas 0.20.3
#     Uninstalling pandas-0.20.3:
#       Successfully uninstalled pandas-0.20.3
# ...
# You are using pip version 10.0.1, however version 19.1.1 is available.
# You should consider upgrading via the 'pip install --upgrade pip' command.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %matplotlib inline

# %%
pd.__version__
# Out:
# '0.23.0'

# %% [markdown]
# ## Taking a look at the Movies dataset
# This data shows the movies based on their title and the year of release

# %%
movies = pd.read_csv('titles.csv.bz2', compression='bz2')
movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244914 entries, 0 to 244913
# Data columns (total 2 columns):
# title    244914 non-null object
# year     244914 non-null int64
# dtypes: int64(1), object(1)
# memory usage: 3.7+ MB

# %%
movies.head()
# Out:
#                                           title  year
# 0                        The Ticket to the Life  2009
# 1  Parallel Worlds: A New Rock Music Experience  2016
# 2                     Morita - La hija de Jesus  2008
# 3                                           Gun  2017
# 4                        Love or Nothing at All  2014

# %%
movies.notnull().all()
# Out:
# title    True
# year     True
# dtype: bool

# %% [markdown]
# ## Taking a look at the Cast dataset
#
# This data shows the cast (actors, actresses, supporting roles) for each movie
#
# - The attribute `n` basically tells the importance of the cast role, lower the number, more important the role.
# - Supporting cast usually don't have any value for `n`

# %%
cast = pd.read_csv('cast.csv.bz2', compression='bz2')
cast.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3786176 entries, 0 to 3786175
# Data columns (total 6 columns):
# title        object
# year         int64
# name         object
# type         object
# character    object
# n            float64
# dtypes: float64(1), int64(1), object(4)
# memory usage: 173.3+ MB

# %%
cast.head(10)
# Out:
#                                                title  year  \
# 0                                     Closet Monster  2015
# 1                                    Suuri illusioni  1985
# 2                                Battle of the Sexes  2017
# 3                               Secret in Their Eyes  2015
# 4                                         Steve Jobs  2015
# 5                             Straight Outta Compton  2015
# 6                             Straight Outta Compton  2015
# 7                                     For Thy Love 2  2009
# 8  Lapis, Ballpen at Diploma, a True to Life Journey  2014
# 9                                       Desire (III)  2014
#
#                         name   type                               character  \
# 0                   Buffy #1  actor                                 Buffy 4
# 1                     Homo $  actor                                  Guests
# 2                    $hutter  actor                         Bobby Riggs Fan
# ...

# %% [markdown]
# ## Taking a look at the Release dataset
#
# This data shows details of when each movie was release in each country with the release date

# %%
release_dates = pd.read_csv('release_dates.csv.bz2', compression='bz2', parse_dates=['date'], infer_datetime_format=True)
release_dates.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 479488 entries, 0 to 479487
# Data columns (total 4 columns):
# title      479488 non-null object
# year       479488 non-null int64
# country    479488 non-null object
# date       479488 non-null datetime64[ns]
# dtypes: datetime64[ns](1), int64(1), object(2)
# memory usage: 14.6+ MB

# %%
release_dates.head()
# Out:
#                     title  year      country       date
# 0   #73, Shaanthi Nivaasa  2007        India 2007-06-15
# 1                   #BKKY  2016     Cambodia 2017-10-12
# 2                 #Beings  2015      Romania 2015-01-29
# 3               #Captured  2017          USA 2017-09-05
# 4  #Ewankosau saranghaeyo  2015  Philippines 2015-01-21

# %% [markdown]
# # Section I - Basic Querying, Filtering and Transformations

# %% [markdown]
# ### What is the total number of movies?

# %%
#All datasets
print(movies.head())
print(cast.head())
print(release_dates.head())
print(movies.shape)
# Out:
#                                           title  year
# 0                        The Ticket to the Life  2009
# 1  Parallel Worlds: A New Rock Music Experience  2016
# 2                     Morita - La hija de Jesus  2008
# 3                                           Gun  2017
# 4                        Love or Nothing at All  2014
#                   title  year      name   type                character     n
# 0        Closet Monster  2015  Buffy #1  actor                  Buffy 4  31.0
# 1       Suuri illusioni  1985    Homo $  actor                   Guests  22.0
# 2   Battle of the Sexes  2017   $hutter  actor          Bobby Riggs Fan  10.0
# 3  Secret in Their Eyes  2015   $hutter  actor          2002 Dodger Fan   NaN
# 4            Steve Jobs  2015   $hutter  actor  1988 Opera House Patron   NaN
#                     title  year      country       date
# 0   #73, Shaanthi Nivaasa  2007        India 2007-06-15
# 1                   #BKKY  2016     Cambodia 2017-10-12
# ...

# %%
len(movies)
# Out:
# 244914

# %% [markdown]
# ### List all Batman movies ever made

# %%
batman_df = movies[movies.title == 'Batman']
print('Total Batman Movies:', len(batman_df))
batman_df
# Out:
# Total Batman Movies: 2
#          title  year
# 52734   Batman  1943
# 150621  Batman  1989

# %% [markdown]
# ### List all Batman movies ever made - the right approach

# %%
batman_df = movies[movies.title.str.contains('Batman', case=False)]
print('Total Batman Movies:', len(batman_df))
batman_df.head(10)
# Out:
# Total Batman Movies: 35
#                                              title  year
# 16813                              Batman: Anarchy  2016
# 30236                               Batman Forever  1995
# 31674                                Batman Untold  2010
# 31711  Scooby-Doo & Batman: the Brave and the Bold  2018
# 41881                  Batman the Rise of Red Hood  2018
# 43484        Batman: Return of the Caped Crusaders  2016
# 46333                               Batman & Robin  1997
# 51811                              Batman Revealed  2012
# 52734                                       Batman  1943
# 56029                 Batman Beyond: Rising Knight  2014

# %% [markdown]
# ### Display the top 15 Batman movies in the order they were released

# %%
batman_df.sort_values(by=['year'], ascending=True).iloc[:15]
# Out:
#                                title  year
# 52734                         Batman  1943
# 100056              Batman and Robin  1949
# 161439                Batman Dracula  1964
# 84327          Alyas Batman at Robin  1965
# 68364                   James Batman  1966
# 161527             Batman: The Movie  1966
# 56159          Batman Fights Dracula  1967
# 168504         Fight! Batman, Fight!  1973
# 150621                        Batman  1989
# 156239         Alyas Batman en Robin  1991
# 156755                Batman Returns  1992
# 63366   Batman: Mask of the Phantasm  1993
# 30236                 Batman Forever  1995
# 46333                 Batman & Robin  1997
# 208220                 Batman Begins  2005

# %% [markdown]
# ### Section I - Q1 : List all the 'Harry Potter' movies from the most recent to the earliest

# %%
release_dates.head()
release_dates[release_dates.title.str.contains('Harry Potter',case=False)].sort_values(by=['date'],ascending=False)
# Out:
#                                                title  year  \
# 150239  Harry Potter and the Deathly Hallows: Part 2  2011
# 150238  Harry Potter and the Deathly Hallows: Part 2  2011
# 150237  Harry Potter and the Deathly Hallows: Part 2  2011
# 150171  Harry Potter and the Deathly Hallows: Part 1  2010
# 150236  Harry Potter and the Deathly Hallows: Part 2  2011
# 150235  Harry Potter and the Deathly Hallows: Part 2  2011
# 150234  Harry Potter and the Deathly Hallows: Part 2  2011
# 150233  Harry Potter and the Deathly Hallows: Part 2  2011
# 150232  Harry Potter and the Deathly Hallows: Part 2  2011
# 150231  Harry Potter and the Deathly Hallows: Part 2  2011
# 150230  Harry Potter and the Deathly Hallows: Part 2  2011
# 150229  Harry Potter and the Deathly Hallows: Part 2  2011
# 150227  Harry Potter and the Deathly Hallows: Part 2  2011
# 150228  Harry Potter and the Deathly Hallows: Part 2  2011
# 150226  Harry Potter and the Deathly Hallows: Part 2  2011
# ...

# %% [markdown]
# ### How many movies were made in the year 2017?

# %%
len(movies[movies.year == 2017])
# Out:
# 11474

# %% [markdown]
# ### Section I - Q2 : How many movies were made in the year 2015?

# %%
len(movies[movies.year==2015])
# Out:
# 8702

# %% [markdown]
# ### Section I - Q3 : How many movies were made from 2000 till 2018?
# - You can chain multiple conditions using OR (`|`) as well as AND (`&`) depending on the condition

# %%
pd.DataFrame(pd.value_counts(movies.year)).sort_index().loc[2000:2018].sum()
# Out:
# year    114070
# dtype: int64

# %% [markdown]
# ### Section I - Q4: How many movies are titled "Hamlet"?

# %%
len(movies[movies.title.str.contains('Hamlet')])
# movies.title.apply(lambda x: x.contains('Hamlet'))
# Out:
# 57

# %% [markdown]
# ### Section I - Q5: List all movies titled "Hamlet"
# - The movies should only have been released on or after the year 2000
# - Display the movies based on the year they were released (earliest to most recent)

# %%
movies[((movies.title.str.contains('Hamlet')) & (movies.year>2000))].sort_values(by=['year'])
# (or)
movies.loc[(movies.title.str.contains('Hamlet')) & (movies.year>2000),:].sort_values(by='year')
# Out:
#                                           title  year
# 55525                    Hamlet in the Hamptons  2002
# 137905                                 Hamlet_X  2003
# 218468                                 Hamlet X  2004
# 40045                               Hamlet (II)  2005
# 152920          Dogg's Hamlet, Cahoot's Macbeth  2005
# 200246  The Tragedy of Hamlet Prince of Denmark  2007
# 176528                              Hamlet (II)  2007
# 156899                             Hamlet (III)  2007
# 141237                                 Hamlet 2  2008
# 52408                 Hamlet the Vampire Slayer  2008
# 191734                           Kitchen Hamlet  2009
# 1931                                     Hamlet  2009
# 227953                                   Hamlet  2011
# 220674                     Hamlet Demonstration  2011
# 51236                            Hamlet Unbound  2012
# 17833                             Zombie Hamlet  2012
# ...

# %% [markdown]
# ### Section I - Q6: How many roles in the movie "Inception" are of the supporting cast (extra credits)
# - supporting cast are NOT ranked by an "n" value (NaN)
# - check for how to filter based on nulls

# %%
# pd.value_counts(cast.type[cast.type.notnull()])
# cast.head()
# print(cast.shape)
# (cast.n.notnull()==False).sum()
len(cast[(cast.title.str.contains('Inception',case=False))&((cast.n.notnull())==False)])
# Out:
# 36

# %% [markdown]
# ### Section I - Q7: How many roles in the movie "Inception" are of the main cast
# - main cast always have an 'n' value

# %%
# print(len(cast))
# print(len(cast[((cast.n.notnull())==False)])+len(cast[((cast.n.notnull())==True)]))\
len(cast[(cast.title.str.contains('Inception',case=False))&((cast.n.notnull())==True)])
# Out:
# 51

# %% [markdown]
# ### Section I - Q8: Show the top ten cast (actors\actresses) in the movie "Inception"
# - support cast always have an 'n' value
# - remember to sort!

# %%
cast[cast.title.str.contains('Inception',case=False) & cast.n.notnull()==True].sort_values(by='n')
# Out:
#              title  year                  name     type  \
# 590576   Inception  2010     Leonardo DiCaprio    actor
# 859993   Inception  2010  Joseph Gordon-Levitt    actor
# 3387147  Inception  2010            Ellen Page  actress
# 940923   Inception  2010             Tom Hardy    actor
# 2406531  Inception  2010          Ken Watanabe    actor
# 1876301  Inception  2010            Dileep Rao    actor
# 1615709  Inception  2010        Cillian Murphy    actor
# 183937   Inception  2010          Tom Berenger    actor
# 2765969  Inception  2010      Marion Cotillard  actress
# 1826027  Inception  2010    Pete Postlethwaite    actor
# 326745   Inception  2010         Michael Caine    actor
# 910757   Inception  2010            Lukas Haas    actor
# 1309851  Inception  2010            Tai-Li Lee    actor
# 2932657  Inception  2010          Claire Geare  actress
# 1668790  Inception  2010          Magnus Nolan    actor
# 2932664  Inception  2010          Taylor Geare  actress
# ...

# %% [markdown]
# ### Section I - Q9:
#
# (A) List all movies where there was a character 'Albus Dumbledore'
#
# (B) Now modify the above to show only the actors who played the character 'Albus Dumbledore'
# - For Part (B) remember the same actor might play the same role in multiple movies

# %%
cast.head()
set(cast[cast.character.str.contains('Albus Dumbledore',case=False)]['name'])
# Out:
# {'Dane Farwell',
#  "George (X) O'Connor",
#  'Michael Gambon',
#  'Richard Harris',
#  'Timothy Tedmanson',
#  'Toby Regbo'}

# %% [markdown]
# ### Section I - Q10:
#
# (A) How many roles has 'Keanu Reeves' played throughout his career?
#
# (B) List the leading roles that 'Keanu Reeves' played on or after 1999 in order by year.

# %%
#A.
set(cast[cast.name.str.contains('Keanu Reeves',case=False)]['character'])
# Out:
# {'Alex Wyler',
#  'Bob Arctor',
#  'Chevalier Danceny',
#  'Chris Nadeau',
#  'Chris Townsend',
#  "Conor O'Neill",
#  'Detective Galban',
#  'Detective Tom Ludlow',
#  'Dogstar',
#  'Don John',
#  'Donaka Mark',
#  'Donnie Barksdale',
#  'Dr. Beckham',
#  'Eddie Kasalivich',
#  'Evan',
#  'Griffin',
#  'Hank',
#  'Harry',
#  'Heaver',
#  'Henry Torne',
#  'Himself',
#  'Jack Traven',
#  'Jjaks Clayton',
#  'John',
#  'John Constantine',
#  'John Wick',
#  'Johnny Mnemonic',
#  'Johnny Utah',
#  'Jonathan Harker',
#  'Julian Gitche',
#  'Julian Mercer',
#  'Kai',
#  'Keanu',
#  'Keanu Reeves',
#  'Kevin Lomax',
#  'Klaatu',
#  'Lucas Hill',
#  'Marlon',
#  'Martin Loader',
#  'Matt',
#  'Nelson Moss',
#  'Neo',
#  'Ortiz the Dog Boy',
#  'Paul Sutton',
#  'Perry Lyman',
#  'Ramsey',
#  'Ron Petrie',
#  'Rupert Marshetta',
#  'Scott Favor',
#  'Shane Falco',
#  'Siddhartha',
#  'Ted',
#  'The Dream',
#  'Tod',
#  'Tommy Warneki',
#  'Winston Connelly'}

# %%
#B.
cast[cast.name.str.contains('Keanu Reeves',case=False) & (cast.year>=1999)].sort_values(by=['year','n']).groupby('year')['character','n'].first()
# Out:
#                  character     n
# year
# 1999                   Neo   1.0
# 2000           Shane Falco   1.0
# 2001         Conor O'Neill   1.0
# 2003         Julian Mercer   3.0
# 2005      John Constantine   1.0
# 2006            Alex Wyler   1.0
# 2008  Detective Tom Ludlow   1.0
# 2009          Chris Nadeau  16.0
# 2010           Henry Torne   1.0
# 2012                  John   NaN
# 2013                   Kai   1.0
# 2014             John Wick   1.0
# 2015                  Evan   1.0
# 2016                Ramsey   1.0
# 2017             John Wick   1.0
# 2018            Lucas Hill   1.0
# 2019             John Wick   NaN

# %%
# cast[cast.name.str.contains('Keanu Reeves',case=False)].groupby(['year','n']).size()

# %% [markdown]
# ### Section I - Q11:
#
# (A) List the total number of actor and actress roles available from 1950 - 1960
#
# (B) List the total number of actor and actress roles available from 2007 - 2017

# %%
#A.
cast.head()
cast[(cast.year>=1950) & (cast.year<=1960)].groupby(['type']).agg({'type':'count'})
# Out:
#            type
# type
# actor    171302
# actress   63333

# %%
#B.
cast[(cast.year>=2007) & (cast.year<=2017)].groupby(['type']).agg({'type':'count'})
# Out:
#            type
# type
# actor    922782
# actress  529631

# %% [markdown]
# ### Section I - Q12:
#
# (A) List the total number of leading roles available from 2000 to present
#
# (B) List the total number of non-leading roles available from 2000 - present (exclude support cast)
#
# (C) List the total number of support\extra-credit roles available from 2000 - present

# %%
#A.
cast.head()
cast[(cast.year>=2000) & (cast.n==1) & (cast.n.notnull())].sort_values(by=['year','n']).groupby('year').agg({'n':'count'})
# Out:
#          n
# year
# 2000  2033
# 2001  2095
# 2002  2213
# 2003  2202
# 2004  2391
# 2005  2623
# 2006  2882
# 2007  2964
# 2008  3256
# 2009  3685
# 2010  3624
# 2011  4076
# 2012  4153
# 2013  4303
# 2014  4399
# 2015  4386
# 2016  4346
# 2017  3938
# 2018   967
# 2019    28
# 2020     4

# %%
# B.
cast[(cast.year>=2000) & (cast.n!=1) & (cast.n.notnull())].sort_values(by=['year','n']).groupby('year').agg({'n':'count'})
# Out:
#           n
# year
# 2000  37247
# 2001  39172
# 2002  39952
# 2003  40546
# 2004  42102
# 2005  47110
# 2006  52215
# 2007  52750
# 2008  56606
# 2009  63803
# 2010  60163
# 2011  67628
# 2012  69565
# 2013  70371
# 2014  70393
# 2015  67809
# 2016  63923
# 2017  50222
# 2018   9942
# 2019    187
# 2020      4

# %%
# C.
cast[(cast.year>=2000) & (cast.n.notnull()==False)].sort_values(by=['year','n']).groupby('year').agg({'year':'count'})
#for validation
# cast[(cast.year>=2000) & (cast.n.notnull()==False) &(cast.year==2000)]
# Out:
#         year
# year
# 2000   11997
# 2001   12431
# 2002   13122
# 2003   15143
# 2004   20111
# 2005   25698
# 2006   30912
# 2007   34595
# 2008   40332
# 2009   51221
# 2010   51332
# 2011   55954
# 2012   62232
# 2013   67747
# 2014   76215
# 2015   80279
# 2016   90863
# 2017  105280
# 2018   40395
# 2019    1363
# 2020     182
# 2021      35
# 2022      16
# 2023       2
# 2024      15
# 2025       9
# 2115       3

# %% [markdown]
# # Section II - Aggregations, Transformations and Visualizations

# %% [markdown]
# ## What are the top ten most common movie names of all time?

# %%
top_ten = movies.title.value_counts()[:10]
top_ten
# Out:
# Hamlet                  20
# Carmen                  17
# Macbeth                 16
# Temptation              12
# Maya                    12
# The Outsider            12
# The Three Musketeers    11
# Othello                 11
# Freedom                 11
# Honeymoon               11
# Name: title, dtype: int64

# %% [markdown]
# ### Plot the top ten common movie names of all time

# %%
top_ten.plot(kind='barh')

# %% [markdown]
# ### Section II - Q1:  Which years in the 2000s saw the most movies released? (Show top 3)

# %%
release_dates.head()
# Out:
#                     title  year      country       date
# 0   #73, Shaanthi Nivaasa  2007        India 2007-06-15
# 1                   #BKKY  2016     Cambodia 2017-10-12
# 2                 #Beings  2015      Romania 2015-01-29
# 3               #Captured  2017          USA 2017-09-05
# 4  #Ewankosau saranghaeyo  2015  Philippines 2015-01-21

# %%
release_dates[release_dates.year>=2000].groupby('year').agg({'title':'count'}).sort_values(by='title',ascending=False).iloc[:3,:]
# Out:
#       title
# year
# 2016  17548
# 2014  17519
# 2015  16639

# %% [markdown]
# ### Section II - Q2: # Plot the total number of films released per-decade (1890, 1900, 1910,....)
# - Hint: Dividing the year and multiplying with a number might give you the decade the year falls into!
# - You might need to sort before plotting

# %%
df_count=release_dates.groupby(release_dates.year//10*10).agg({'year':'count'})\
.rename(columns={'year':'count_decade'}).reset_index().sort_values(by='year')
df_count.plot(kind='scatter',x='year',y='count_decade')

# %% [markdown]
# ### Section II - Q3:
#
# (A) What are the top 10 most common character names in movie history?
#
# (B) Who are the top 10 people most often credited as "Herself" in movie history?
#
# (C) Who are the top 10 people most often credited as "Himself" in movie history?

# %%
# A.
pd.value_counts(cast.character,dropna=True)[:10]
# Out:
# Himself        20746
# Dancer         12477
# Extra          11948
# Reporter        8434
# Student         7773
# Doctor          7669
# Party Guest     7245
# Policeman       7029
# Nurse           6999
# Bartender       6802
# Name: character, dtype: int64

# %%
# B.
pd.value_counts(cast[cast.character=='Herself']['name'])[:10]
# Out:
# Queen Elizabeth II           12
# Luisa Horga                   9
# Joyce Brothers                9
# Mar?a Luisa (V) Mart?n        9
# Margaret Thatcher             8
# Hillary Clinton               8
# Mar?a Isabel (III) Mart?n     6
# Sumie Sakai                   6
# Marilyn Monroe                6
# Oprah Winfrey                 6
# Name: name, dtype: int64

# %%
# C.
pd.value_counts(cast[cast.character=='Himself']['name'])[:10]
# Out:
# Adolf Hitler             99
# Richard Nixon            44
# Ronald Reagan            41
# John F. Kennedy          37
# George W. Bush           25
# Winston Churchill        24
# Martin Luther King       23
# Ron Jeremy               22
# Bill Clinton             22
# Franklin D. Roosevelt    21
# Name: name, dtype: int64

# %% [markdown]
# ### Section II - Q4:
#
# (A) What are the top 10 most frequent roles that start with the word "Zombie"?
#
# (B) What are the top 10 most frequent roles that start with the word "Police"?
#
# - Hint: The `startswith()` function might be useful

# %%
pd.value_counts(cast[cast.character.str.startswith('Zombie')]['character'],dropna=True)[:10]
# Out:
# Zombie                         6264
# Zombie Horde                    206
# Zombie - Protestor - Victim      78
# Zombie Extra                     70
# Zombie Dancer                    43
# Zombie #1                        36
# Zombie Girl                      36
# Zombie #2                        31
# Zombie Vampire                   25
# Zombie Victim                    22
# Name: character, dtype: int64

# %%
pd.value_counts(cast[cast.character.str.startswith('Police')]['character'],dropna=True)[:10]
# Out:
# Policeman              7029
# Police Officer         4808
# Police Inspector        742
# Police Sergeant         674
# Police officer          539
# Police                  456
# Policewoman             415
# Police Chief            410
# Police Captain          387
# Police Commissioner     337
# Name: character, dtype: int64

# %% [markdown]
# ### Section II - Q5: Plot how many roles 'Keanu Reeves' has played in each year of his career.

# %%
cast.head()
df_q5=cast[cast.name=='Keanu Reeves'].groupby('year',as_index=False).agg({'n':'count'}).rename(columns={'n':'n_movies'})
df_q5
df_q5.plot(kind='scatter',x='year',y='n_movies')

# %% [markdown]
# ### Section II - Q6: Plot the cast positions (n-values) of Keanu Reeve's roles through his career over the years.

# %%
cast.head()
df_q6=cast[cast.name.str.contains("Keanu Reeves")].sort_values(by='year')
df_q6.plot(kind='scatter',x=['year'],y=['n'])

# %% [markdown]
# ### Section II - Q7: Plot the number of "Hamlet" films made by each decade

# %%
cast.head()
df_q7=cast[cast.title.str.contains('Hamlet')].groupby(cast.year//10*10).agg({'year':'count'}).rename(columns={'year':'count_no'})
df_q7=df_q7.reset_index()
df_q7.plot(kind='scatter',x=['year'],y=['count_no'])

# %% [markdown]
# ### Section II - Q8:
#
# (A) How many leading roles were available to both actors and actresses, in the 1960s (1960-1969)?
#
# (B) How many leading roles were available to both actors and actresses, in the 2000s (2000-2009)?
#
# - Hint: A specific value of n might indicate a leading role

# %%
# A.
cast[(cast.year>=1960) & (cast.year<=1969) & (cast.n==1)].groupby(cast.type).size()

# %%
# B.
cast[(cast.year>=2000) & (cast.year<=2009) & (cast.n==1)].groupby(cast.type).size()

# %% [markdown]
# ### Section II - Q9: List, in order by year, each of the films in which Frank Oz has played more than 1 role.

# %%
cast.head()
df_9=cast[cast.name=='Frank Oz'].groupby(cast.year).agg({'year':'count'}).rename(columns={'year':'count_film'}).reset_index()
# df_9.reset_index()
df_9[df_9.count_film >1]

# %% [markdown]
# ### Section II - Q10: List each of the characters that Frank Oz has portrayed at least twice

# %%
df_q10=pd.DataFrame(cast[cast.name=='Frank Oz']['character'].value_counts())
df_q10[df_q10.character>=2].index
# pd.DataFrame(cast[cast.name=='Frank Oz']['character'].value_counts())

# %% [markdown]
# # Section III - Advanced Merging, Querying and Visualizations

# %% [markdown]
# ## Make a bar plot with the following conditions
# - Frequency of the number of movies with "Christmas" in their title
# - Movies should be such that they are released in the USA.
# - Show the frequency plot by month

# %%
christmas = release_dates[(release_dates.title.str.contains('Christmas')) & (release_dates.country == 'USA')]
christmas.date.dt.month.value_counts().sort_index().plot(kind='bar')

# %% [markdown]
# ### Section III - Q1: Make a bar plot with the following conditions
# - Frequency of the number of movies with "Summer" in their title
# - Movies should be such that they are released in the USA.
# - Show the frequency plot by month

# %%
release_dates.head()
df_q1=release_dates[release_dates.title.str.contains('Summer') & (release_dates.country=='USA')]
df_q1.date.dt.month.value_counts().plot(kind='bar')

# %% [markdown]
# ### Section III - Q2: Make a bar plot with the following conditions
# - Frequency of the number of movies with "Action" in their title
# - Movies should be such that they are released in the USA.
# - Show the frequency plot by week

# %%
df_q1=release_dates[release_dates.title.str.contains('Summer') & (release_dates.country=='USA')]
df_q1.date.dt.week.value_counts().plot(kind='bar')

# %% [markdown]
# ### Section III - Q3: Show all the movies in which Keanu Reeves has played the lead role along with their   release date in the USA sorted by the date of release
# - Hint: You might need to join or merge two datasets!

# %%
 cast.head()
df_q2=cast[(cast.name=='Keanu Reeves') & (cast.n==1)]
# print(df_q2.shape)
pd.merge(left=df_q2,right=release_dates[release_dates.country=='USA'],how='inner',on='title').sort_values(by='date')
# Out:
#                                title  year_x          name   type  \
# 14                             Speed    1994  Keanu Reeves  actor
# 15                             Speed    1994  Keanu Reeves  actor
# 18                    Sweet November    2001  Keanu Reeves  actor
# 24                  The Night Before    1988  Keanu Reeves  actor
# 3   Bill & Ted's Excellent Adventure    1989  Keanu Reeves  actor
# 2         Bill & Ted's Bogus Journey    1991  Keanu Reeves  actor
# 13                     Little Buddha    1993  Keanu Reeves  actor
# 16                             Speed    1994  Keanu Reeves  actor
# 10                   Johnny Mnemonic    1995  Keanu Reeves  actor
# 1               A Walk in the Clouds    1995  Keanu Reeves  actor
# 4                     Chain Reaction    1996  Keanu Reeves  actor
# 6                  Feeling Minnesota    1996  Keanu Reeves  actor
# 21              The Devil's Advocate    1997  Keanu Reeves  actor
# ...

# %% [markdown]
# ### Section III - Q4: Make a bar plot showing the months in which movies with Keanu Reeves tend to be released in the USA?

# %%
pd.merge(left=df_q2,right=release_dates[release_dates.country=='USA'],how='inner',on='title').sort_values(by='date').date\
.dt.month.plot(kind='bar')

# %% [markdown]
# ### Section III - Q5: Make a bar plot showing the years in which movies with Ian McKellen tend to be released in the USA?

# %%
pd.merge(cast[cast.name.str.contains('Ian McKellen')],release_dates[release_dates.country=='USA'],how='inner',on='title')['date']\
.dt.year.value_counts().plot(kind='bar')
